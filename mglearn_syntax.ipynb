# %%
import mglearn.datasets as mn

# %%
x,y=mn.make_forge()
print(x[:5],y[:5])
# Out:
# [[ 9.96346605  4.59676542]
#  [11.0329545  -0.16816717]
#  [11.54155807  5.21116083]
#  [ 8.69289001  1.54322016]
#  [ 8.1062269   4.28695977]] [1 0 1 0 0]
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)

# %%
print(x[:,0])
# Out:
# [ 9.96346605 11.0329545  11.54155807  8.69289001  8.1062269   8.30988863
#  11.93027136  9.67284681  8.34810316  8.67494727  9.17748385 10.24028948
#   8.68937095  8.92229526  9.49123469  9.25694192  7.99815287  8.18378052
#   8.7337095   9.32298256 10.06393839  9.50048972  8.34468785  9.50169345
#   9.15072323 11.563957  ]

# %%
import matplotlib.pyplot as plt

# %%
import mglearn
mglearn.discrete_scatter(x[:,0],x[:,1],y)

# %%
# pl=plt.pyplot()
# 
plt.scatter(x[:,0],x[:,1],c=y)
plt.legend(["Class 0", "Class 1"])
